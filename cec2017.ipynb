# %%
# pip install opfunu

# %%
import pandas as pd
import numpy
import random
import math
import matplotlib.pyplot as plt
from scipy.stats import friedmanchisquare as friedman
import scipy.stats as stats
from scipy.stats import chi2
from scipy.stats import f
from scipy.stats import friedmanchisquare as friedman
import numpy as np

# %% [markdown]
# # D = 30

# %%
from opfunu.cec_based.cec2017 import *
benchmark_function = [F12017,
                     F22017,
                     F32017,
                     F42017,
                     F52017,
                     F62017,
                     F72017,
                     F82017,
                     F92017,
                     F102017,
                     F112017,
                     F122017,
                     F132017,
                     F142017,
                     F152017,
                     F162017,
                     F172017,
                     F182017,
                     F192017,
                     F202017,
                     F212017,
                     F222017,
                     F232017,
                     F242017,
                     F252017, 
                     F262017,
                     F272017,
                     F282017,
                     F292017
                     ]

for i in benchmark_function:
    lowerbound = -100
    upperbound = 100
    dimension = 30
    
    SearchAgents = 50
    Max_iterations = int(np.ceil(10000*dimension/SearchAgents)) #1000
    print(f'for {i}')
    func = i(ndim=dimension)
    fitness = func
    
    Best_score, Best_pos, SGHO_curve, average, std_ = \
    SGHO(SearchAgents, Max_iterations, lowerbound, upperbound, dimension, fitness)
    best_ft.append(Best_score)
    avg.append(average)
    std.append(std_)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from opfunu.cec_based.cec2017 import *

def func_plot_cec(func, ax, dimension=2):
    lb = -100
    ub = 100
    x = np.linspace(lb, ub, 400)
    y = np.linspace(lb, ub, 400)
    X, Y = np.meshgrid(x, y)
    
    if dimension == 2:
        Z = np.array([[func.evaluate(np.array([x_val, y_val])) for x_val in x] for y_val in y])
    elif dimension == 30:
        Z = np.zeros(X.shape)
        for i in range(Z.shape[0]):
            for j in range(Z.shape[1]):
                Z[i, j] = func.evaluate(np.array([X[i, j], Y[i, j]] + [0] * (dimension - 2)))

    ax.plot_surface(X, Y, Z, cmap='viridis')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('F')

# Create instances of the CEC benchmark functions with the desired dimension (e.g., 30)
benchmark_functions = [
    F12017(ndim=30), F22017(ndim=30), F32017(ndim=30), F42017(ndim=30), F52017(ndim=30),
#     F62017(ndim=30), F72017(ndim=30), F82017(ndim=30), F92017(ndim=30), F102017(ndim=30),
#     F112017(ndim=30), F122017(ndim=30), F132017(ndim=30), F142017(ndim=30), F152017(ndim=30),
#     F162017(ndim=30), F172017(ndim=30), F182017(ndim=30), F192017(ndim=30), F202017(ndim=30),
#     F212017(ndim=30), F222017(ndim=30), F232017(ndim=30), F242017(ndim=30), F252017(ndim=30),
#     F262017(ndim=30), F272017(ndim=30), F282017(ndim=30), F292017(ndim=30)
]

fig = plt.figure(figsize=(15, 30))  # Adjust figure size as needed

for i, func in enumerate(benchmark_functions):
    ax = fig.add_subplot(7, 4, i + 1, projection='3d')  # Adjust the number of rows and columns as needed
    func_plot_cec(func, ax, dimension=30)  # Use dimension=2 for 2D functions
    ax.set_title(f'F{i+1} (CEC 2017)')

plt.subplots_adjust(top=0.9, wspace=0.3, hspace=0.5)  # Adjust spacing as needed
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from opfunu.cec_based.cec2017 import *

def func_plot_cec(func, ax, dimension=2):
    lb = -100
    ub = 100
    x = np.linspace(lb, ub, 400)
    y = np.linspace(lb, ub, 400)
    X, Y = np.meshgrid(x, y)
    
    if dimension == 2:
        Z = np.array([[func.evaluate(np.array([x_val, y_val])) for x_val in x] for y_val in y])
    elif dimension == 30:
        Z = np.zeros(X.shape)
        for i in range(Z.shape[0]):
            for j in range(Z.shape[1]):
                Z[i, j] = func.evaluate(np.array([X[i, j], Y[i, j]] + [0] * (dimension - 2)))

    ax.plot_surface(X, Y, Z, cmap='viridis')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('F')

# Create instances of the CEC benchmark functions with the desired dimension (e.g., 30)
benchmark_functions = [
#     F12017(ndim=30), F22017(ndim=30), F32017(ndim=30), F42017(ndim=30), F52017(ndim=30),
     F62017(ndim=30), F72017(ndim=30), F82017(ndim=30), F92017(ndim=30), F102017(ndim=30),
#     F112017(ndim=30), F122017(ndim=30), F132017(ndim=30), F142017(ndim=30), F152017(ndim=30),
#     F162017(ndim=30), F172017(ndim=30), F182017(ndim=30), F192017(ndim=30), F202017(ndim=30),
#     F212017(ndim=30), F222017(ndim=30), F232017(ndim=30), F242017(ndim=30), F252017(ndim=30),
#     F262017(ndim=30), F272017(ndim=30), F282017(ndim=30), F292017(ndim=30)
]

fig = plt.figure(figsize=(15, 30))  # Adjust figure size as needed

for i, func in enumerate(benchmark_functions):
    ax = fig.add_subplot(7, 4, i + 1, projection='3d')  # Adjust the number of rows and columns as needed
    func_plot_cec(func, ax, dimension=30)  # Use dimension=2 for 2D functions
    ax.set_title(f'F{i+6} (CEC 2017)')

plt.subplots_adjust(top=0.9, wspace=0.3, hspace=0.5)  # Adjust spacing as needed
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from opfunu.cec_based.cec2017 import *

def func_plot_cec(func, ax, dimension=2):
    lb = -100
    ub = 100
    x = np.linspace(lb, ub, 400)
    y = np.linspace(lb, ub, 400)
    X, Y = np.meshgrid(x, y)
    
    if dimension == 2:
        Z = np.array([[func.evaluate(np.array([x_val, y_val])) for x_val in x] for y_val in y])
    elif dimension == 30:
        Z = np.zeros(X.shape)
        for i in range(Z.shape[0]):
            for j in range(Z.shape[1]):
                Z[i, j] = func.evaluate(np.array([X[i, j], Y[i, j]] + [0] * (dimension - 2)))

    ax.plot_surface(X, Y, Z, cmap='viridis')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('F')

# Create instances of the CEC benchmark functions with the desired dimension (e.g., 30)
benchmark_functions = [
#     F12017(ndim=30), F22017(ndim=30), F32017(ndim=30), F42017(ndim=30), F52017(ndim=30),
#     F62017(ndim=30), F72017(ndim=30), F82017(ndim=30), F92017(ndim=30), F102017(ndim=30),
     F112017(ndim=30), F122017(ndim=30), F132017(ndim=30), F142017(ndim=30), F152017(ndim=30),
#     F162017(ndim=30), F172017(ndim=30), F182017(ndim=30), F192017(ndim=30), F202017(ndim=30),
#     F212017(ndim=30), F222017(ndim=30), F232017(ndim=30), F242017(ndim=30), F252017(ndim=30),
#     F262017(ndim=30), F272017(ndim=30), F282017(ndim=30), F292017(ndim=30)
]

fig = plt.figure(figsize=(15, 30))  # Adjust figure size as needed

for i, func in enumerate(benchmark_functions):
    ax = fig.add_subplot(7, 4, i + 1, projection='3d')  # Adjust the number of rows and columns as needed
    func_plot_cec(func, ax, dimension=30)  # Use dimension=2 for 2D functions
    ax.set_title(f'F{i+11} (CEC 2017)')

plt.subplots_adjust(top=0.9, wspace=0.3, hspace=0.5)  # Adjust spacing as needed
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from opfunu.cec_based.cec2017 import *

def func_plot_cec(func, ax, dimension=2):
    lb = -100
    ub = 100
    x = np.linspace(lb, ub, 400)
    y = np.linspace(lb, ub, 400)
    X, Y = np.meshgrid(x, y)
    
    if dimension == 2:
        Z = np.array([[func.evaluate(np.array([x_val, y_val])) for x_val in x] for y_val in y])
    elif dimension == 30:
        Z = np.zeros(X.shape)
        for i in range(Z.shape[0]):
            for j in range(Z.shape[1]):
                Z[i, j] = func.evaluate(np.array([X[i, j], Y[i, j]] + [0] * (dimension - 2)))

    ax.plot_surface(X, Y, Z, cmap='viridis')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('F')

# Create instances of the CEC benchmark functions with the desired dimension (e.g., 30)
benchmark_functions = [
#     F12017(ndim=30), F22017(ndim=30), F32017(ndim=30), F42017(ndim=30), F52017(ndim=30),
#     F62017(ndim=30), F72017(ndim=30), F82017(ndim=30), F92017(ndim=30), F102017(ndim=30),
#     F112017(ndim=30), F122017(ndim=30), F132017(ndim=30), F142017(ndim=30), F152017(ndim=30),
     F162017(ndim=30), F172017(ndim=30), F182017(ndim=30), F192017(ndim=30), F202017(ndim=30),
#     F212017(ndim=30), F222017(ndim=30), F232017(ndim=30), F242017(ndim=30), F252017(ndim=30),
#     F262017(ndim=30), F272017(ndim=30), F282017(ndim=30), F292017(ndim=30)
]

fig = plt.figure(figsize=(15, 30))  # Adjust figure size as needed

for i, func in enumerate(benchmark_functions):
    ax = fig.add_subplot(7, 4, i + 1, projection='3d')  # Adjust the number of rows and columns as needed
    func_plot_cec(func, ax, dimension=30)  # Use dimension=2 for 2D functions
    ax.set_title(f'F{i+16} (CEC 2017)')

plt.subplots_adjust(top=0.9, wspace=0.3, hspace=0.5)  # Adjust spacing as needed
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from opfunu.cec_based.cec2017 import *

def func_plot_cec(func, ax, dimension=2):
    lb = -100
    ub = 100
    x = np.linspace(lb, ub, 400)
    y = np.linspace(lb, ub, 400)
    X, Y = np.meshgrid(x, y)
    
    if dimension == 2:
        Z = np.array([[func.evaluate(np.array([x_val, y_val])) for x_val in x] for y_val in y])
    elif dimension == 30:
        Z = np.zeros(X.shape)
        for i in range(Z.shape[0]):
            for j in range(Z.shape[1]):
                Z[i, j] = func.evaluate(np.array([X[i, j], Y[i, j]] + [0] * (dimension - 2)))

    ax.plot_surface(X, Y, Z, cmap='viridis')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('F')

# Create instances of the CEC benchmark functions with the desired dimension (e.g., 30)
benchmark_functions = [
#     F12017(ndim=30), F22017(ndim=30), F32017(ndim=30), F42017(ndim=30), F52017(ndim=30),
#     F62017(ndim=30), F72017(ndim=30), F82017(ndim=30), F92017(ndim=30), F102017(ndim=30),
#     F112017(ndim=30), F122017(ndim=30), F132017(ndim=30), F142017(ndim=30), F152017(ndim=30),
#     F162017(ndim=30), F172017(ndim=30), F182017(ndim=30), F192017(ndim=30), F202017(ndim=30),
     F212017(ndim=30), F222017(ndim=30), F232017(ndim=30), F242017(ndim=30), F252017(ndim=30),
#     F262017(ndim=30), F272017(ndim=30), F282017(ndim=30), F292017(ndim=30)
]

fig = plt.figure(figsize=(15, 30))  # Adjust figure size as needed

for i, func in enumerate(benchmark_functions):
    ax = fig.add_subplot(7, 4, i + 1, projection='3d')  # Adjust the number of rows and columns as needed
    func_plot_cec(func, ax, dimension=30)  # Use dimension=2 for 2D functions
    ax.set_title(f'F{i+21} (CEC 2017)')

plt.subplots_adjust(top=0.9, wspace=0.3, hspace=0.5)  # Adjust spacing as needed
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from opfunu.cec_based.cec2017 import *

def func_plot_cec(func, ax, dimension=2):
    lb = -100
    ub = 100
    x = np.linspace(lb, ub, 400)
    y = np.linspace(lb, ub, 400)
    X, Y = np.meshgrid(x, y)
    
    if dimension == 2:
        Z = np.array([[func.evaluate(np.array([x_val, y_val])) for x_val in x] for y_val in y])
    elif dimension == 30:
        Z = np.zeros(X.shape)
        for i in range(Z.shape[0]):
            for j in range(Z.shape[1]):
                Z[i, j] = func.evaluate(np.array([X[i, j], Y[i, j]] + [0] * (dimension - 2)))

    ax.plot_surface(X, Y, Z, cmap='viridis')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('F')

# Create instances of the CEC benchmark functions with the desired dimension (e.g., 30)
benchmark_functions = [
#     F12017(ndim=30), F22017(ndim=30), F32017(ndim=30), F42017(ndim=30), F52017(ndim=30),
#     F62017(ndim=30), F72017(ndim=30), F82017(ndim=30), F92017(ndim=30), F102017(ndim=30),
#     F112017(ndim=30), F122017(ndim=30), F132017(ndim=30), F142017(ndim=30), F152017(ndim=30),
#     F162017(ndim=30), F172017(ndim=30), F182017(ndim=30), F192017(ndim=30), F202017(ndim=30),
#     F212017(ndim=30), F222017(ndim=30), F232017(ndim=30), F242017(ndim=30), F252017(ndim=30),
     F262017(ndim=30), F272017(ndim=30), F282017(ndim=30), F292017(ndim=30)
]

fig = plt.figure(figsize=(15, 30))  # Adjust figure size as needed

for i, func in enumerate(benchmark_functions):
    ax = fig.add_subplot(7, 4, i + 1, projection='3d')  # Adjust the number of rows and columns as needed
    func_plot_cec(func, ax, dimension=30)  # Use dimension=2 for 2D functions
    ax.set_title(f'F{i+26} (CEC 2017)')

plt.subplots_adjust(top=0.9, wspace=0.3, hspace=0.5)  # Adjust spacing as needed
plt.tight_layout()
plt.show()
